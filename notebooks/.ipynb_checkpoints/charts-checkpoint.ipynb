# %%
from IPython.display import Image

print("=== CONFUSION MATRIX ===")
display(Image("confusion_matrix.png"))

print("=== ROC CURVE ===")
display(Image("roc_curve.png"))

print("=== SHAP FEATURE IMPORTANCE ===")
display(Image("shap_importance.png"))

print("=== SHAP DIRECTION SUMMARY ===")
display(Image("shap_summary.png"))

print("=== SINGLE PATIENT EXPLANATION ===")
display(Image("shap_single_patient.png"))
# Out:
# === CONFUSION MATRIX ===
# === ROC CURVE ===
# === SHAP FEATURE IMPORTANCE ===
# === SHAP DIRECTION SUMMARY ===
# === SINGLE PATIENT EXPLANATION ===
